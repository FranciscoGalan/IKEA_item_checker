# %% [markdown]
# # IKEA item checker
#
# This notebooks checks whether a product is available at the IKEA website.
#
# *Most of the following steps are based on the book Web Scraping with Python, by Ryan Mitchell*.

# %%
# Import libraries
from urllib.request import urlopen
from bs4 import BeautifulSoup
import time
import pandas as pd
import re
import numpy as np

# %% [markdown]
# ## 1. Get website information

# %%
url = 'https://www.ikea.com/mx/es/p/poaeng-sillon-chapa-abedul-hillared-beige-s09306567/'

# %% [markdown]
# We will use `urlopen(url).read()`, but one could also get the html code using `requests.get(url).content`. We use `try` to handle possible exceptions.

# %%
try:
    html = urlopen(url)
    print('Status code: ', html.getcode())

except HTTPError as e: # Page is not found
    print(e)

except URLError as e: # Page is down
    print('The server could not be found!')
    
else:
    pass
# Out:
# Status code:  200

# %% [markdown]
# Let's transform the html code to a Beautiful Soup object (a more manageable format).

# %%
bs = BeautifulSoup(html, 'lxml') # This parser is slightly better than 'html.parser'
                                 # Another good parser is 'html5lib'

# %%
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="es-MX">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    POÄNG Sillón - chapa abedul/Hillared beige - IKEA
#   </title>
#   <meta content="IKEA - POÄNG, Sillón, chapa abedul/Hillared beige, El respaldo alto proporciona un buen apoyo al cuello. Con nuestro surtido variado de cojines podrás renovar fácilmente el aspecto de POÄNG y de la habitación. Si lo combinas con el taburete POÄNG, el sillón será aún más cómodo." name="description"/>
#   <meta content="IKEA - POÄNG, Sillón, chapa abedul/Hillared beige, El respaldo alto proporciona un buen apoyo al cuello. Con nuestro surtido variado de cojines podrás renovar fácilmente el aspecto de POÄNG y de la habitación. Si lo combinas con el taburete POÄNG, el sillón será aún más cómodo." property="og:description"/>
#   <meta content="POÄNG, Sillón" name="keywords"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="POÄNG Sillón - chapa abedul/Hillared beige - IKEA" property="og:title"/>
#   <meta content="product" property="og:type"/>
#   <meta content="https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg" property="og:image"/>
#   <meta content="https://www.ikea.com/mx/es/p/poaeng-sillon-chapa-abedul-hillared-beige-s09306567/" property="og:url"/>
#   <meta content="IKEA" property="og:site_name"/>
#   <link href="https://www.ikea.com/mx/es/p/poaeng-sillon-chapa-abedul-hillared-beige-s09306567/" rel="canonical"/>
#   <!-- Range PIP head - Version:v56 -->
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="/mx/es/products/stylesheets/range-pip-styles.dde18e05938451a90531.css" rel="stylesheet"/>
#   <!-- 2021-05-11T11:07:33.194Z, Navigera 2.4.4 -->
#   <link data-opti-default="false" data-opti-edge="false" data-opti-web="false" href="https://www.ikea.com/mx/es/header-footer/styles/main.1a637de5bbf37bed9589.css" id="nav-styles" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Noto+Sans:400,400i,700,700i&amp;display=swap" rel="stylesheet"/>
#   <link href="https://www.ikea.com/mx/es/header-footer/styles/notoLatin.82c59126c38025027d8c.css" rel="stylesheet"/>
#   <!-- 2021-05-12 16:08:08 CEST Search: refs/tags/v8.76.0-62d6a79694c183571ba95b677179aa4fa6745eff -->
#   <script nomodule="">
#    var head  = document.getElementsByTagName("head")[0];
#       var link  = document.createElement("link");
#       link.rel  = "stylesheet";
#       link.href = "https://www.ikea.com/mx/es/search/box-legacy.f849b6f5.css";
#       head.appendChild(link);
#   </script>
#   <link href="https://www.ikea.com/mx/es/search/box.f849b6f5.css" rel="stylesheet"/>
#   <!-- RecommendationsStyle: version: bd3f9a8, site-folder: mx/es -->
#   <link href="https://www.ikea.com/mx/es/recommendations/panels/rec.0a488c57.css" rel="stylesheet"/>
#   <!-- /RecommendationsStyle -->
#   <!-- gitVersion: 20210511211300, siteFolder: mx/es -->
#   <link href="https://www.ikea.com/mx/es/insp-feed/content-gallery-app/feed.25cf3909.css" rel="stylesheet"/>
#   <link href="https://www.ikea.com/mx/es/static/favicon.951c4869fb7244d6c3aa.ico" rel="shortcut icon"/>
#   <link href="https://www.ikea.com/mx/es/local-extensions/header-footer/styles/local_em.a4069d94f1fdca2f50a47cda.css" rel="stylesheet"/>
#   <link href="https://www.ikea.com/mx/es/local-extensions/header-footer/styles/libs.f4dfda74c869db594af0d8aa.css" rel="stylesheet"/>
#   <link href="https://ww8.ikea.com/seaapp3/assets/css/icons.css" rel="stylesheet"/>
#   <script data-type="utag-data">
#    var utag_data = {"site_platform":"m2","visit_country":"mx","visit_language":"es","page_name":"product information page>prodview>09306567","page_type":"product information page","site_section":"product information page","event_array":["product_view"],"product_ids":["09306567"],"product_type":"SPR","product_names":["poäng"],"product_item_names":["poäng sillón chapa abedul/hillared beige"],"price":["2999"],"product_prices":["2585.34"],"product_vats":["413.66"],"tax":["413.66"],"currency_code":"MXN","product_series":"POÄNG serie","product_collections":"no collections","category":"10687","category_local":"Sillones de tela","product_variant":"Hillared beige","subproducts":"81305807,40466723","pip_per_visit":"+1","prodview_type":"PIP","hfb_no":"01","hfb_name":"Living room seating","pra_no":"012","pra_name":"Armchairs, footstool & sofa tables","pa_no":"0125","pa_name":"Armchairs,","product_images_no":"5"}
#   </script>
#   <script type="text/javascript">
#    window["optimizelyDatafile"] = {"version": "4", "rollouts": [], "typedAudiences": [], "anonymizeIP": true, "projectId": "14982271315", "variables": [], "featureFlags": [], "experiments": [{"status": "Running", "audienceConditions": ["or", "20232280545"], "audienceIds": ["20232280545"], "variations": [{"variables": [], "id": "20189976699", "key": "original"}, {"variables": [], "id": "20199639715", "key": "bullets_small"}, {"variables": [], "id": "20217140815", "key": "benefit_medium"}, {"variables": [], "id": "20183815645", "key": "bullets_medium"}, {"variables": [], "id": "20209287843", "key": "benefit_large"}, {"variables": [], "id": "20182547867", "key": "bullets_large"}], "id": "20188531311", "key": "product_information_relaunch", "layerId": "20160709976", "trafficAllocation": [{"entityId": "20189976699", "endOfRange": 167}, {"entityId": "20182547867", "endOfRange": 999}, {"entityId": "20183815645", "endOfRange": 1667}, {"entityId": "20182547867", "endOfRange": 1834}, {"entityId": "20183815645", "endOfRange": 1999}, {"entityId": "20189976699", "endOfRange": 2832}, {"entityId": "20199639715", "endOfRange": 3332}, {"entityId": "20183815645", "endOfRange": 3499}, {"entityId": "20199639715", "endOfRange": 3832}, {"entityId": "20209287843", "endOfRange": 4665}, {"entityId": "20217140815", "endOfRange": 4999}, {"entityId": "20209287843", "endOfRange": 5000}, {"entityId": "20199639715", "endOfRange": 5167}, {"entityId": "20217140815", "endOfRange": 5666}, {"entityId": "", "endOfRange": 6667}, {"entityId": "20209287843", "endOfRange": 6833}, {"entityId": "", "endOfRange": 8333}, {"entityId": "20217140815", "endOfRange": 8500}, {"entityId": "", "endOfRange": 10000}], "forcedVariations": {}}], "audiences": [{"id": "20232280545", "conditions": "[\"and\", [\"or\", [\"or\", {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"AT\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"AU\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"BE\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"CA\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"CH\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"CZ\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"DE\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"DK\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"ES\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"FI\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"FR\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"GB\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"HR\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"HU\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"IE\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"IT\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"JP\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"KR\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"MX\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"MY\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"NL\"}, {\"match\": \"exact\", \"name\": \"country\", \"type\": \"custom_attribute\", \"value\": \"NO\"}, {\"match\": \"exact\", \"name\": \"country\",  ...
#   </script>
#  </head>
#  <body data-version="v56">
#   <a class="skip-to-content" href="#content">
#    Saltar al contenido principal
#   </a>
#   <!-- 2021-05-11T11:07:33.208Z, Navigera 2.4.4 -->
#   <a class="hnf-skip-to-content hnf-link" href="#hnf-content">
#    Saltar al contenido principal
#   </a>
#   <div class="hnf-messages">
#    <div class="hnf-message hnf-message--green" data-config='{
#     "startdate": "",
#     "enddate": ""
#   }' id="value-proposition-message">
#    </div>
#   </div>
#   <div class="hnf-header-hamburger hnf-page-container">
#    <div class="hnf-page-container__inner">
#     <div class="hnf-page-container__aside">
#      <button aria-label="Menú" class="hnf-btn hnf-btn--small hnf-btn--icon-tertiary" title="Menú" type="button">
#       <span class="hnf-btn__inner">
#        <svg class="svg-icon hnf-svg-icon" fill="none" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <path clip-rule="evenodd" d="M20 8H4V6h16v2zm0 5H4v-2h16v2zm0 5H4v-2h16v2z" fill-rule="evenodd">
#         </path>
#        </svg>
#       </span>
#      </button>
#     </div>
#    </div>
#   </div>
#   <header class="hnf-header">
#    <div class="hnf-page-container">
#     <div class="hnf-page-container__inner">
#      <div class="hnf-header__container hnf-page-container__main">
#       <div class="hnf-header__logo">
#        <a class="hnf-link" href="https://www.ikea.com/mx/es/">
#         <img alt="IKEA" src="https://www.ikea.com/mx/es/static/ikea-logo.951c4869fb7244d6c3aa.svg" title="IKEA"/>
#         <span class="hnf-header__sr-only">
#          IKEA
#         </span>
#        </a>
#       </div>
#       <nav class="hnf-header__nav">
#        <ul class="hnf-header__nav__main" data-header-links="">
#         <li>
#          <a class="hnf-link" data-index="0" data-products-link="" href="https://www.ikea.com/mx/es/cat/productos-products/">
#           Productos
#          </a>
#         </li>
#         <li>
#          <a class="hnf-link" data-index="1" href="https://www.ikea.com/mx/es/rooms/">
#           Habitaciones
#          </a>
#         </li>
#        </ul>
#       </nav>
#       <div class="hnf-header__search">
#        <div data-baseurl="https://www.ikea.com" data-css-scope="search-box" data-locale="es-MX" data-namespace="search-box" data-version="refs/tags/v8.76.0-62d6a79694c183571ba95b677179aa4fa6745eff">
#         <div>
#          <form action="https://www.ikea.com/mx/es/search/" class="search-box" role="search">
#           <div class="search-wrapper">
#            <div class="search-field">
#             <input aria-label="Busque productos, inspiración o novedades" aria-placeholder="Busca productos, inspiración o novedades" autocapitalize="off" autocomplete="off" autocorrect="off" class="search-field__input" maxlength="150" name="q" placeholder="¿Qué es lo que buscas?" spellcheck="false" type="search"/>
#             <span class="search-box__button-wrapper">
#             </span>
#            </div>
#           </div>
#          </form>
#         </div>
#        </div>
#       </div>
#       <ul class="hnf-header__icons" data-shopping-links="">
#        <li class="hnf-header__search-btn">
#         <button aria-expanded="false" aria-label="Buscar" class="hnf-btn hnf-btn--small hnf-btn--icon-tertiary" title="Buscar" type="button">
#          <span class="hnf-btn__inner">
#           <svg class="svg-icon hnf-svg-icon" fill="none" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <path clip-rule="evenodd" d="M13.98 15.395a6.294 6.294 0 111.414-1.414l4.602 4.601-1.414 1.414-4.602-4.601zm.607-5.101a4.294 4.294 0 11-8.587 0 4.294 4.294 0 018.587 0z" fill-rule="evenodd">
#            </path>
#           </svg>
#          </span>
#         </button>
#        </li>
#        <li class="hnf-header__order-tracking-link">
#         <a aria-label="Dar seguimiento al pedido" class="hnf-btn hnf-btn--small hnf-btn--icon-tertiary" href="https://www.ikea.com/mx/es/customer-service/track-manage-order/" rel="nofollow" title="Dar seguimiento al pedido">
#          <span class="hnf-btn__inner">
#           <svg class="svg-icon hnf-svg-icon hnf-btn__icon" fill="none" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <path clip-rule="evenodd" d="M1 4h15v3h3.025l3.979 5.685V18h-2.657a3.252 3.252 0 01-6.186 0h-3.905a3.251 3.251 0 01-6.186 0H1V4zm3.07 12a3.251 3.251 0 016.186 0H14V6H3v10h1.07zM16 14a3.252 3.252 0 014.347 2h.657v-2.685L17.984 9H16v5zm-8.837 1.75a1.25 1.25 0 100 2.5 1.25 1.25 0 000-2.5zm10.09 0a1.25 1.25 0 100 2.5 1.25 1.25 0 000-2.5z" fill-rule="evenodd">
#            </path>
#           </svg>
#          </span>
#         </a>
#        </li>
#        <li class="hnf-header__profile-link">
#         <a aria-label="Mi perfil" class="hnf-btn hnf-btn--small hnf-btn--icon-tertiary" data-profile-link="" href="https://www.ikea.com/mx/es/profile/home/" rel="nofollow" title="Mi perfil">
#          <span class="hnf-btn__inner">
#           <svg class="svg-icon hnf-svg-icon hnf-btn__icon" fill="none" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <path clip-rule="evenodd" d="M10.672 6.468c.274-.281.68-.47 1.35-.47.397 0 .705.083.953.222.24.134.438.33.593.619l.003.006c.14.254.237.618.237 1.14 0 .786-.204 1.245-.48 1.528l-.004.005c-.276.288-.68.476-1.334.476-.386 0-.696-.082-.956-.224a1.49 1.49 0 01-.589-.614c-.145-.275-.242-.652-.242-1.17 0-.791.204-1.245.47-1.518zm1.35-2.472c-1.084 0-2.054.326-2.784 1.077-.738.758-1.036 1.78-1.036 2.912 0 .766.143 1.483.477 2.112l.004.006a3.488 3.488 0 001.377 1.415l.006.004a3.94 3.94 0 001.924.473c1.082 0 2.048-.333 2.775-1.09.741-.762 1.044-1.785 1.044-2.92 0-.763-.142-1.478-.482-2.1a3.488 3.488 0 00-1.376-1.412c-.585-.328-1.238-.477-1.93-.477zM6.469 16.858a3.25 3.25 0 011.29-1.357c.558-.32 1.283-.505 2.221-.505h4.04c.938 0 1.663.186 2.22.505.568.33.993.777 1.29 1.357.304.59.47 1.294.47 2.138v1h2v-1c0-1.112-.22-2.138-.69-3.052a5.322 5.322 0 00-2.073-2.177c-.927-.532-2.015-.77-3.217-.77H9.98c-1.114 0-2.248.211-3.222.773a5.25 5.25 0 00-2.068 2.174c-.47.914-.69 1.94-.69 3.052v1h2v-1c0-.844.166-1.548.47-2.138z" fill-rule="evenodd">
#            </path>
#           </svg>
#          </span>
#         </a>
#        </li>
#        <li class="hnf-header__shopping-list-link" data-shoppinglist-icon="favorite">
#         <a aria-label="Lista de la compra" class="hnf-btn hnf-btn--small hnf-btn--icon-tertiary" href="https://order.ikea.com/mx/es/checkout/shoppinglist/" rel="nofollow" title="Lista de la compra">
#          <span class="hnf-btn__inner">
#           <svg class="svg-icon hnf-svg-icon hnf-btn__icon" fill="none" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <path clip-rule="evenodd" d="M12.336 5.52055C14.2336 3.62376 17.3096 3.62401 19.2069 5.52129C20.2067 6.52115 20.6796 7.85005 20.6259 9.15761C20.6151 12.2138 18.4184 14.8654 16.4892 16.6366C15.4926 17.5517 14.5004 18.2923 13.7593 18.8036C13.3879 19.0598 13.0771 19.2601 12.8574 19.3973C12.7475 19.466 12.6601 19.519 12.5992 19.5555C12.5687 19.5737 12.5448 19.5879 12.5279 19.5978L12.5079 19.6094L12.502 19.6129L12.5001 19.614C12.5001 19.614 12.4989 19.6147 11.9999 18.748C11.501 19.6147 11.5005 19.6144 11.5005 19.6144L11.4979 19.6129L11.4919 19.6094L11.472 19.5978C11.4551 19.5879 11.4312 19.5737 11.4007 19.5555C11.3397 19.519 11.2524 19.466 11.1425 19.3973C10.9227 19.2601 10.612 19.0598 10.2405 18.8036C9.49947 18.2923 8.50726 17.5517 7.51063 16.6366C5.58146 14.8654 3.38477 12.2139 3.37399 9.15765C3.32024 7.85008 3.79314 6.52117 4.79301 5.52129C6.69054 3.62376 9.76704 3.62376 11.6646 5.52129L11.9993 5.856L12.3353 5.52129L12.336 5.52055ZM11.9999 18.748L11.5005 19.6144L11.9999 19.9019L12.4989 19.6147L11.9999 18.748ZM11.9999 17.573C12.1727 17.462 12.384 17.3226 12.6236 17.1573C13.3125 16.6821 14.2267 15.9988 15.1366 15.1634C17.0157 13.4381 18.6259 11.2919 18.6259 9.13506V9.11213L18.627 9.08922C18.6626 8.31221 18.3844 7.52727 17.7926 6.9355C16.6762 5.81903 14.866 5.81902 13.7495 6.9355L13.7481 6.93689L11.9965 8.68166L10.2504 6.9355C9.13387 5.81903 7.3237 5.81903 6.20722 6.9355C5.61546 7.52727 5.33724 8.31221 5.3729 9.08922L5.37395 9.11213V9.13507C5.37395 11.2919 6.98418 13.4381 8.86325 15.1634C9.77312 15.9988 10.6874 16.6821 11.3762 17.1573C11.6159 17.3226 11.8271 17.462 11.9999 17.573Z" fill-rule="evenodd">
#            </path>
#           </svg>
#          </span>
#         </a>
#        </li>
#        <li class="hnf-header__shopping-cart-link">
#         <a aria-label="Carrito de compras" class="hnf-btn hnf-btn--small hnf-btn--icon-tertiary" href="https://secure.ikea.com/mx/es/mcommerce/shoppingcart" rel="nofollow" title="Carrito de compras">
#          <span class="hnf-btn__inner js-shopping-cart-icon" data-market-code="es-MX">
#           <span class="hnf-header__cart-counter" style="display:none">
#           </span>
#           <svg class="svg-icon hnf-svg-icon hnf-svg-bag-default hnf-btn__icon" fill="none" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <path clip-rule="evenodd" d="M11 4h-.563l-.292.48-3.357 5.517H1.72l.31 1.243 1.621 6.485a3 3 0 002.91 2.272H17.44a3 3 0 002.91-2.272l1.621-6.485.31-1.243h-5.069L13.854 4.48 13.562 4H11zm3.87 5.997L12.438 6h-.876L9.129 9.997h5.741zM5.591 17.24l-1.31-5.243h15.438l-1.31 5.243a1 1 0 01-.97.757H6.562a1 1 0 01-.97-.757z" fill-rule="evenodd">
#            </path>
#           </svg>
#           <svg class="svg-icon hnf-svg-icon hnf-svg-bag-added hnf-btn__icon" fill="none" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <path clip-rule="evenodd" d="M10.437 4h3.125l.292.48 3.357 5.517h5.069l-.31 1.243-.69 2.76h-2.06l.5-2.003H4.281l1.31 5.243a1 1 0 00.97.757H15v2H6.562a3 3 0 01-2.91-2.272L2.03 11.24l-.31-1.243h5.068l3.357-5.517.292-.48zm2 2l2.433 3.997H9.13L11.56 6h.877z" fill-rule="evenodd">
#            </path>
#            <path d="M21 17.5a2.5 2.5 0 11-5 0 2.5 2.5 0 015 0z" fill="#0058A3">
#            </path>
#           </svg>
#          </span>
#         </a>
#        </li>
#        <li class="hnf-header__hamburger">
#         <button aria-expanded="false" aria-label="Menú" class="hnf-btn hnf-btn--small hnf-btn--icon-tertiary" title="Menú" type="button">
#          <span class="hnf-btn__inner">
#           <svg class="svg-icon hnf-svg-icon hnf-btn__icon" fill="none" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <path clip-rule="evenodd" d="M20 8H4V6h16v2zm0 5H4v-2h16v2zm0 5H4v-2h16v2z" fill-rule="evenodd">
#            </path>
#           </svg>
#          </span>
#         </button>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </header>
#   <div id="hnf-header-filler">
#   </div>
#   <aside aria-hidden="true" class="hnf-menu hnf-menu--hidden" data-title-more="Más">
#    <div class="hnf-menu__top">
#     <div class="hnf-menu__close">
#      <button aria-expanded="true" aria-label="Cerrar el menú" class="hnf-btn hnf-btn--small hnf-btn--icon-tertiary" id="hnf-menu-close-btn" title="Cerrar el menú" type="button">
#       <span class="hnf-btn__inner">
#        <svg class="svg-icon hnf-svg-icon" fill="none" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <path clip-rule="evenodd" d="M12 13.415l4.95 4.95 1.414-1.415-4.95-4.95 4.95-4.95-1.415-1.413-4.95 4.95-4.949-4.95L5.636 7.05l4.95 4.95-4.95 4.95 1.414 1.414 4.95-4.95z" fill-rule="evenodd">
#         </path>
#        </svg>
#       </span>
#      </button>
#     </div>
#     <div class="hnf-menu__logo">
#      <a class="hnf-link" href="https://www.ikea.com/mx/es/">
#       <img alt="IKEA" src="https://www.ikea.com/mx/es/static/ikea-logo.951c4869fb7244d6c3aa.svg" title="IKEA"/>
#       <span class="hnf-menu__sr-only">
#        IKEA
#       </span>
#      </a>
#     </div>
#     <div class="hnf-menu__search">
#      <button aria-expanded="false" class="hnf-btn hnf-btn--small hnf-btn--icon-tertiary" id="hnf-menu-search-btn" title="Buscar" type="button">
#       <span class="hnf-btn__inner">
#        <svg class="svg-icon hnf-svg-icon" fill="none" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <path clip-rule="evenodd" d="M13.98 15.395a6.294 6.294 0 111.414-1.414l4.602 4.601-1.414 1.414-4.602-4.601zm.607-5.101a4.294 4.294 0 11-8.587 0 4.294 4.294 0 018.587 0z" fill-rule="evenodd">
#         </path>
#        </svg>
#        <span class="hnf-btn__label">
#         Buscar
#        </span>
#       </span>
#      </button>
#     </div>
#     <div class="hnf-menu__back hnf-menu__back--hidden">
#      <button aria-expanded="true" aria-label="Volver" class="hnf-btn hnf-btn--small hnf-btn--icon-tertiary" id="hnf-menu-back-btn" title="Volver" type="button">
#       <span class="hnf-btn__inner">
#        <svg class="svg-icon hnf-svg-icon" fill="none" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <path clip-rule="evenodd" d="M3.999 12l8 8 1.414-1.413L7.827 13H20v-2H7.827l5.587-5.587L12 4l-8.001 8z" fill-rule="evenodd">
#         </path>
#        </svg>
#       </span>
#      </button>
#     </div>
#    </div>
#    <div class="hnf-menu__container">
#     <nav aria-hidden="false" class="hnf-menu__nav">
#      <ul class="hnf-menu__nav__main" data-main-links="">
#       <li>
#        <a class="hnf-link" data-index="0" data-products-link="" data-tracking-label="products" href="https://www.ikea.com/mx/es/cat/productos-products/" role="button">
#         Productos
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-index="1" data-tracking-label="rooms" href="https://www.ikea.com/mx/es/rooms/" role="button">
#         Habitaciones
#        </a>
#       </li>
#       <li>
#        <a class="hnf-menu__nav__main--small hnf-link" data-index="2" data-tracking-label="ideas" href="https://www.ikea.com/mx/es/ideas/" role="button">
#         Ideas
#        </a>
#       </li>
#       <li>
#        <a class="hnf-menu__nav__main--small hnf-link" data-index="3" data-tracking-label="" href="#" role="button">
#         Destacados
#        </a>
#       </li>
#       <li>
#        <a class="hnf-menu__nav__main--small hnf-link" data-index="4" data-tracking-label="" href="#" role="button">
#         Información útil
#        </a>
#       </li>
#      </ul>
#      <ul class="hnf-menu__nav__aux" data-aux-links="">
#       <li>
#        <a class="hnf-link" href="https://www.ikea.com/mx/es/stores/visita-oceania-pubd64fe3b0">
#         Visita IKEA Oceanía
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" href="https://www.ikea.com/mx/es/customer-service/services/">
#         Servicios IKEA
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" href="https://www.ikea.com/mx/es/customer-service/services/seguro-de-hogar-hemsaker-pub293fe740">
#         HEMSÄKER, seguro de hogar
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" href="https://www.ikea.com/mx/es/ikea-business/">
#         IKEA para tu Negocio
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" href="https://family.ikea.mx/">
#         IKEA Family
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" href="https://www.ikea.com/mx/es/profile/home/">
#         Mi perfil
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" href="https://www.ikea.com/mx/es/customer-service/track-manage-order/">
#         Rastrea tu pedido
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" href="https://www.ikea.com/mx/es/customer-service/">
#         Atención al cliente
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <nav aria-hidden="true" class="hnf-menu__nav2 hnf-menu__nav2--hidden" data-index="0">
#      <span class="hnf-menu__heading">
#       Productos
#      </span>
#      <ul aria-label="Submenú para Productos" class="hnf-menu__nav2__main" data-menu-sub1-links="" data-show-rv="1" data-tracking-label="products">
#      </ul>
#      <div class="hnf-loading">
#       <div aria-hidden="true" class="hnf-loading__ball-wrapper">
#        <div class="hnf-loading__ball hnf-loading__ball--active">
#        </div>
#       </div>
#       <a class="hnf-link" data-tracking-label="fu001" href="https://www.ikea.com/mx/es/cat/muebles-fu001/">
#        Muebles
#       </a>
#       <a class="hnf-link" data-tracking-label="bm001" href="https://www.ikea.com/mx/es/cat/camas-y-colchones-bm001/">
#        Camas y colchones
#       </a>
#       <a class="hnf-link" data-tracking-label="st001" href="https://www.ikea.com/mx/es/cat/almacenamiento-y-organizacion-st001/">
#        Almacenamiento y organización
#       </a>
#       <a class="hnf-link" data-tracking-label="ka001" href="https://www.ikea.com/mx/es/cat/cocina-y-electrodomesticos-ka001/">
#        Cocina y electrodomésticos
#       </a>
#       <a class="hnf-link" data-tracking-label="bc001" href="https://www.ikea.com/mx/es/cat/bebes-y-ninos-bc001/">
#        Bebés y niños
#       </a>
#       <a class="hnf-link" data-tracking-label="tl001" href="https://www.ikea.com/mx/es/cat/textiles-tl001/">
#        Textiles
#       </a>
#       <a class="hnf-link" data-tracking-label="de001" href="https://www.ikea.com/mx/es/cat/decoracion-de001/">
#        Decoración
#       </a>
#       <a class="hnf-link" data-tracking-label="li001" href="https://www.ikea.com/mx/es/cat/iluminacion-li001/">
#        Iluminación
#       </a>
#       <a class="hnf-link" data-tracking-label="kt001" href="https://www.ikea.com/mx/es/cat/utensilios-de-cocina-y-vajilla-kt001/">
#        Utensilios de cocina y vajilla
#       </a>
#       <a class="hnf-link" data-tracking-label="ba001" href="https://www.ikea.com/mx/es/cat/productos-para-bano-ba001/">
#        Productos para baño
#       </a>
#       <a class="hnf-link" data-tracking-label="rm001" href="https://www.ikea.com/mx/es/cat/tapetes-y-pisos-rm001/">
#        Tapetes y pisos
#       </a>
#       <a class="hnf-link" data-tracking-label="od001" href="https://www.ikea.com/mx/es/cat/productos-de-exteriores-od001/">
#        Productos de exteriores
#       </a>
#       <a class="hnf-link" data-tracking-label="lc001" href="https://www.ikea.com/mx/es/cat/lavanderia-y-limpieza-lc001/">
#        Lavandería y limpieza
#       </a>
#       <a class="hnf-link" data-tracking-label="hi001" href="https://www.ikea.com/mx/es/cat/mejorando-el-hogar-hi001/">
#        Mejorando el hogar
#       </a>
#       <a class="hnf-link" data-tracking-label="pp001" href="https://www.ikea.com/mx/es/cat/macetas-y-plantas-pp001/">
#        Macetas y plantas
#       </a>
#       <a class="hnf-link" data-tracking-label="he001" href="https://www.ikea.com/mx/es/cat/electronicos-para-el-hogar-he001/">
#        Electrónicos para el hogar
#       </a>
#       <a class="hnf-link" data-tracking-label="pt001" href="https://www.ikea.com/mx/es/cat/accesorios-para-mascotas-pt001/">
#        Accesorios para mascotas
#       </a>
#       <a class="hnf-link" data-tracking-label="hs001" href="https://www.ikea.com/mx/es/cat/hogar-inteligente-hs001/">
#        Hogar inteligente
#       </a>
#      </div>
#     </nav>
#     <nav aria-hidden="true" class="hnf-menu__nav2 hnf-menu__nav2--hidden" data-index="1">
#      <span class="hnf-menu__heading">
#       Habitaciones
#      </span>
#      <ul aria-label="Submenú para Habitaciones" class="hnf-menu__nav2__main hnf-menu__nav2__main--rooms-grid" data-menu-sub2-links="" data-tracking-label="rooms">
#       <li>
#        <a class="hnf-link" data-tracking-label="rooms/bedroom" href="https://www.ikea.com/mx/es/rooms/bedroom/">
#         <span class="mr-aspect-ratio-image mr-aspect-ratio-image--wide">
#          <img alt="Recámara" class="mr-aspect-ratio-image__image" data-src="https://www.ikea.com/images/recamara-ikea-mexico-af108655f8838915559f7555c0e4f98e.jpg?f=xxxs"/>
#         </span>
#         <span class="mr__nav__title">
#          Recámara
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="rooms/dining" href="https://www.ikea.com/mx/es/rooms/dining/">
#         <span class="mr-aspect-ratio-image mr-aspect-ratio-image--wide">
#          <img alt="Comedor" class="mr-aspect-ratio-image__image" data-src="https://www.ikea.com/images/comedor-ikea-1fe6fef8a06d7cdd8dd28e1f28f48ee1.jpg?f=xxxs"/>
#         </span>
#         <span class="mr__nav__title">
#          Comedor
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="rooms/living-room" href="https://www.ikea.com/mx/es/rooms/living-room/">
#         <span class="mr-aspect-ratio-image mr-aspect-ratio-image--wide">
#          <img alt="Sala" class="mr-aspect-ratio-image__image" data-src="https://www.ikea.com/images/living-room-ikea-mexico-2d1a56f4763b3b8a36ebeeec1fbc74d4.jpg?f=xxxs"/>
#         </span>
#         <span class="mr__nav__title">
#          Sala
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="rooms/kitchen" href="https://www.ikea.com/mx/es/rooms/kitchen/">
#         <span class="mr-aspect-ratio-image mr-aspect-ratio-image--wide">
#          <img alt="Cocina" class="mr-aspect-ratio-image__image" data-src="https://www.ikea.com/images/knoxhult-kitchen-1daab150bc32912223768266f9bb8c6d.jpg?f=xxxs"/>
#         </span>
#         <span class="mr__nav__title">
#          Cocina
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="rooms/childrens-room" href="https://www.ikea.com/mx/es/rooms/childrens-room/">
#         <span class="mr-aspect-ratio-image mr-aspect-ratio-image--wide">
#          <img alt="Bebés y niños" class="mr-aspect-ratio-image__image" data-src="https://www.ikea.com/images/habitacion-de-los-ninos-ikea-mexico-ea8653c95760152ba7afd77bdc061584.jpg?f=xxxs"/>
#         </span>
#         <span class="mr__nav__title">
#          Bebés y niños
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="rooms/outdoor" href="https://www.ikea.com/mx/es/rooms/outdoor/">
#         <span class="mr-aspect-ratio-image mr-aspect-ratio-image--wide">
#          <img alt="Jardín y balcón" class="mr-aspect-ratio-image__image" data-src="https://www.ikea.com/images/garden-and-balcony-ikea-singapore-c5c520bb9978b4a7ccc1ac448815adcc.jpg?f=xxxs"/>
#         </span>
#         <span class="mr__nav__title">
#          Jardín y balcón
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="rooms/hallway" href="https://www.ikea.com/mx/es/rooms/hallway/">
#         <span class="mr-aspect-ratio-image mr-aspect-ratio-image--wide">
#          <img alt="Recibidor" class="mr-aspect-ratio-image__image" data-src="https://www.ikea.com/images/recibidor-hallway-ikea-mexico-ca8721dfeb2f65fb10c49af1205437f4.jpg?f=xxxs"/>
#         </span>
#         <span class="mr__nav__title">
#          Recibidor
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="rooms/bathroom" href="https://www.ikea.com/mx/es/rooms/bathroom/">
#         <span class="mr-aspect-ratio-image mr-aspect-ratio-image--wide">
#          <img alt="Baño" class="mr-aspect-ratio-image__image" data-src="https://www.ikea.com/images/bathroom-ikea-singapore-8964536be035b0427533e2084da35525.jpg?f=xxxs"/>
#         </span>
#         <span class="mr__nav__title">
#          Baño
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="rooms/laundry" href="https://www.ikea.com/mx/es/rooms/laundry/">
#         <span class="mr-aspect-ratio-image mr-aspect-ratio-image--wide">
#          <img alt="Lavandería" class="mr-aspect-ratio-image__image" data-src="https://www.ikea.com/images/lavanderia-y-limpieza-81d699e17c1235d29b203ba737596642.jpg?f=xxxs"/>
#         </span>
#         <span class="mr__nav__title">
#          Lavandería
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="rooms/home-office" href="https://www.ikea.com/mx/es/rooms/home-office/">
#         <span class="mr-aspect-ratio-image mr-aspect-ratio-image--wide">
#          <img alt="Oficina en casa" class="mr-aspect-ratio-image__image" data-src="https://www.ikea.com/images/oficina-en-casa-ikea-mexico-e313b789c0288464db7a96b431e1c255.jpg?f=xxxs"/>
#         </span>
#         <span class="mr__nav__title">
#          Oficina en casa
#         </span>
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <nav aria-hidden="true" class="hnf-menu__nav2 hnf-menu__nav2--hidden" data-index="2">
#      <span class="hnf-menu__heading">
#       Ideas
#      </span>
#      <ul aria-label="Submenú para Ideas" class="hnf-menu__nav2__main" data-menu-sub3-links="" data-tracking-label="Ideas">
#       <li>
#        <a class="hnf-link" data-tracking-label="inspiracion-pub29696130" href="https://www.ikea.com/mx/es/ideas/inspiracion-pub29696130">
#         Todas las habitaciones
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="rooms/bedroom/how-to" href="https://www.ikea.com/mx/es/rooms/bedroom/how-to/">
#         Recámara
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="rooms/kitchen/how-to" href="https://www.ikea.com/mx/es/rooms/kitchen/how-to/">
#         Cocina
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="rooms/dining/how-to" href="https://www.ikea.com/mx/es/rooms/dining/how-to/">
#         Comedor
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="rooms/living-room/how-to" href="https://www.ikea.com/mx/es/rooms/living-room/how-to/">
#         Sala
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="rooms/bathroom/how-to" href="https://www.ikea.com/mx/es/rooms/bathroom/how-to/">
#         Baño
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="rooms/childrens-room/how-to" href="https://www.ikea.com/mx/es/rooms/childrens-room/how-to/">
#         Bebés y niños
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="rooms/laundry/how-to" href="https://www.ikea.com/mx/es/rooms/laundry/how-to/">
#         Lavandería
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <nav aria-hidden="true" class="hnf-menu__nav2 hnf-menu__nav2--hidden" data-index="3">
#      <span class="hnf-menu__heading">
#       Destacados
#      </span>
#      <ul aria-label="Submenú para Destacados" class="hnf-menu__nav2__main" data-menu-sub3-links="" data-tracking-label="Destacados">
#       <li>
#        <a class="hnf-link" data-tracking-label="regalos-ikea-pub43fcad10" href="https://www.ikea.com/mx/es/campaigns/regalos-ikea-pub43fcad10">
#         Regalos IKEA
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="como-dormir-mejor-pubd6545ad0" href="https://www.ikea.com/mx/es/campaigns/como-dormir-mejor-pubd6545ad0">
#         Cómo dormir mejor
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="campaigns" href="https://www.ikea.com/mx/es/campaigns/">
#         Productos destacados
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="aprovecha-al-maximo-la-vida-al-aire-libre-pub2245bad0" href="https://www.ikea.com/mx/es/campaigns/aprovecha-al-maximo-la-vida-al-aire-libre-pub2245bad0">
#         Viviendo en exteriores
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="stores/restaurant" href="https://www.ikea.com/mx/es/stores/restaurant/">
#         Restaurante IKEA
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="organise-your-living-pub0f0f4dc0" href="https://www.ikea.com/mx/es/campaigns/organise-your-living-pub0f0f4dc0">
#         Organiza tu espacio
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="viviendo-con-ninos-soluciones-e-inspiracion-pubbf3d6e70" href="https://www.ikea.com/mx/es/rooms/childrens-room/how-to-plan-buy/viviendo-con-ninos-soluciones-e-inspiracion-pubbf3d6e70">
#         Viviendo con niños
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="nuestra-pasion-por-los-textiles-pub5b8cc5a0" href="https://www.ikea.com/mx/es/campaigns/nuestra-pasion-por-los-textiles-pub5b8cc5a0">
#         Nuestra pasión por los textiles
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="comida-sostenible-para-toda-la-familia-pubabb5a651" href="https://www.ikea.com/mx/es/stores/restaurant/comida-sostenible-para-toda-la-familia-pubabb5a651">
#         Mercado de comida sueca
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="ikea-series-pub1dc960c1" href="https://www.ikea.com/mx/es/rooms/ikea-series-pub1dc960c1">
#         Todas las series de IKEA
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <nav aria-hidden="true" class="hnf-menu__nav2 hnf-menu__nav2--hidden" data-index="4">
#      <span class="hnf-menu__heading">
#       Información útil
#      </span>
#      <ul aria-label="Submenú para Información útil" class="hnf-menu__nav2__main" data-menu-sub3-links="" data-tracking-label="Información útil">
#       <li>
#        <a class="hnf-link" data-tracking-label="customer-service/returns-claims/guarantee" href="https://www.ikea.com/mx/es/customer-service/returns-claims/guarantee/">
#         Garantías
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="planners" href="https://www.ikea.com/mx/es/planners/">
#         Herramientas de planeación
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="customer-service/returns-claims/return-policy" href="https://www.ikea.com/mx/es/customer-service/returns-claims/return-policy/">
#         Política de devoluciones
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="customer-service/shopping-at-ikea" href="https://www.ikea.com/mx/es/customer-service/shopping-at-ikea/">
#         Cómo comprar en línea
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="customer-service/track-manage-order" href="https://www.ikea.com/mx/es/customer-service/track-manage-order/">
#         Rastrea tu pedido
#        </a>
#       </li>
#       <li>
#        <a class="hnf-link" data-tracking-label="secure-it-or-return-it-pub6b7f8175" href="https://www.ikea.com/mx/es/customer-service/product-support/secure-it-or-return-it-pub6b7f8175">
#         Asegúralo o devuélvelo
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <div aria-hidden="true" class="hnf-menu__rv hnf-menu__rv--hidden">
#      <span class="hnf-menu__rv__heading">
#       Visto recientemente
#      </span>
#      <div class="hnf-menu__rv__list">
#      </div>
#     </div>
#    </div>
#    <div class="hnf-menu__alternate">
#     <div class="hnf-quantity-dropdown hnf-switch-language">
#      <select aria-label="Selecciona tu idioma preferido">
#       <option value="https://www.ikea.com/mx/es/">
#        Español
#       </option>
#       <option value="https://www.ikea.com/mx/en/">
#        English
#       </option>
#      </select>
#      <svg class="svg-icon hnf-svg-icon hnf-svg-icon--100 hnf-quantity-dropdown__chevron" fill="none" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#       <path clip-rule="evenodd" d="M12 17.06l-8-8 1.413-1.415L12 14.232l6.587-6.586L20 9.061l-8.001 8z" fill-rule="evenodd">
#       </path>
#      </svg>
#     </div>
#     <a class="hnf-link hnf-btn hnf-btn-change-country" href="https://www.ikea.com">
#      <svg class="svg-icon hnf-svg-icon hnf-btn-change-country__globe" fill="none" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#       <path clip-rule="evenodd" d="M13.747 18.177C12.948 19.774 12.215 20 12 20c-.215 0-.948-.226-1.747-1.823A10.786 10.786 0 019.47 16h5.06a10.83 10.83 0 01-.783 2.177zM14.889 14H9.11A17.735 17.735 0 019 12c0-.695.04-1.364.111-2h5.777a18.04 18.04 0 01.001 4zm1.695 2c-.266 1.217-.65 2.307-1.121 3.214A8.035 8.035 0 0018.93 16h-2.346zm3.164-2H16.9a19.826 19.826 0 000-4h2.848A8 8 0 0120 12a8 8 0 01-.252 2zm-.818-6a8.035 8.035 0 00-3.467-3.214c.472.907.855 1.997 1.121 3.214h2.346zm-4.4 0a10.79 10.79 0 00-.783-2.177C12.948 4.226 12.215 4 12 4c-.215 0-.948.226-1.747 1.823A10.787 10.787 0 009.47 8h5.06zM7.416 8c.266-1.217.65-2.307 1.121-3.214A8.035 8.035 0 005.07 8h2.346zm-3.164 2A8.015 8.015 0 004 12c0 .69.088 1.36.252 2H7.1a19.829 19.829 0 010-4H4.252zm3.164 6H5.07a8.035 8.035 0 003.467 3.214c-.472-.907-.855-1.997-1.121-3.214zM22 12c0-5.523-4.477-10-10-10S2 6.477 2 12s4.477 10 10 10 10-4.477 10-10z" fill-rule="evenodd">
#       </path>
#      </svg>
#      Cambiar el país
#     </a>
#    </div>
#   </aside>
#   <div class="hnf-overlay">
#   </div>
#   <div class="hnf-location-popup-modal-wrapper location-popup--hidden" data-geo-markets="ES" data-site-folder="mx/es" id="location-popup">
#   </div>
#   <div id="hnf-content" tabindex="-1">
#   </div>
#   <main class="main no-outline" id="content" role="main" tabindex="-1">
#    <div class="range-revamp-page-container" data-cs-capture="">
#     <div class="range-revamp-page-container__inner">
#      <div class="range-revamp-page-container__main">
#       <div>
#        <div class="bc-breadcrumb">
#         <nav aria-label="Breadcrumb" class="bc-breadcrumb__nav" role="navigation">
#          <ol class="bc-breadcrumb__list" data-breadcrumb-links="">
#           <li class="bc-breadcrumb__list-item">
#            <a class="bc-breadcrumb__link bc-link bc-link--black" data-tracking-label="products" href="https://www.ikea.com/mx/es/cat/productos-products/">
#             <span>
#              Productos
#             </span>
#            </a>
#           </li>
#           <li class="bc-breadcrumb__list-item">
#            <a class="bc-breadcrumb__link bc-link bc-link--black" data-tracking-label="products | fu001" href="https://www.ikea.com/mx/es/cat/muebles-fu001/">
#             <span>
#              Muebles
#             </span>
#            </a>
#           </li>
#           <li class="bc-breadcrumb__list-item">
#            <a class="bc-breadcrumb__link bc-link bc-link--black" data-tracking-label="products | fu001 | fu006" href="https://www.ikea.com/mx/es/cat/sillones-y-chaise-longues-fu006/">
#             <span>
#              Sillones y chaise longues
#             </span>
#            </a>
#           </li>
#           <li class="bc-breadcrumb__list-item">
#            <a class="bc-breadcrumb__link bc-link bc-link--black" data-tracking-label="products | fu001 | fu006 | 10687" href="https://www.ikea.com/mx/es/cat/sillones-de-tela-10687/">
#             <span>
#              Sillones de tela
#             </span>
#            </a>
#           </li>
#           <li class="bc-breadcrumb__list-item">
#            <a class="bc-breadcrumb__link bc-link bc-link--black" href="https://www.ikea.com/mx/es/p/poaeng-sillon-chapa-abedul-hillared-beige-s09306567/">
#             <span>
#              POÄNG Sillón
#             </span>
#            </a>
#           </li>
#          </ol>
#         </nav>
#        </div>
#        <script type="application/ld+json">
#         {
#   "@context":"https://schema.org",
#   "@type":"BreadcrumbList",
#   "itemListElement": [
#      {
#          "@type" : "ListItem", "position": 1, "name": "Productos", "item": "https://www.ikea.com/mx/es/cat/productos-products/"
#      },
#      {
#          "@type" : "ListItem", "position": 2, "name": "Muebles", "item": "https://www.ikea.com/mx/es/cat/muebles-fu001/"
#      },
#      {
#          "@type" : "ListItem", "position": 3, "name": "Sillones y chaise longues", "item": "https://www.ikea.com/mx/es/cat/sillones-y-chaise-longues-fu006/"
#      },
#      {
#          "@type" : "ListItem", "position": 4, "name": "Sillones de tela", "item": "https://www.ikea.com/mx/es/cat/sillones-de-tela-10687/"
#      }
#
#
#      ,
#      {
#         "@type": "ListItem", "position": 5, "name": "POÄNG Sillón", "item": "https://www.ikea.com/mx/es/p/poaeng-sillon-chapa-abedul-hillared-beige-s09306567/"
#      }
#
#   ]
# }
#        </script>
#       </div>
#       <div class="range-revamp-product__subgrid product-pip js-product-pip" data-online-sellable="false" data-product-id="S09306567" data-product-no="09306567" data-product-price="2999" data-product-type="SPR">
#        <div class="range-revamp-product__left-top range-revamp-product__grid-gap">
#         <div class="js-range-media-grid range-revamp-media-grid" data-initial-props='{"fullMediaList":[{"type":"image","content":{"alt":"POÄNG Sillón, chapa abedul/Hillared beige","id":"0497125_PE628952","imageFileName":"0497125_PE628952_S5.JPG","url":"https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg","type":"MAIN_PRODUCT_IMAGE"}},{"type":"image","content":{"alt":"POÄNG Sillón, chapa abedul/Hillared beige","id":"0837582_PE629074","imageFileName":"0837582_PE629074_S5.JPG","url":"https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0837582_pe629074_s5.jpg","type":"CONTEXT_PRODUCT_IMAGE"}},{"type":"image","content":{"alt":"POÄNG Sillón, chapa abedul/Hillared beige","id":"0837579_PE628955","imageFileName":"0837579_PE628955_S5.JPG","url":"https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0837579_pe628955_s5.jpg","type":"FUNCTIONAL_PRODUCT_IMAGE"}},{"type":"image","content":{"alt":"POÄNG Sillón, chapa abedul/Hillared beige","id":"0837573_PE628954","imageFileName":"0837573_PE628954_S5.JPG","url":"https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0837573_pe628954_s5.jpg","type":"QUALITY_PRODUCT_IMAGE"}},{"type":"image","content":{"alt":"POÄNG Sillón, chapa abedul/Hillared beige","id":"0612906_PE686092","imageFileName":"0612906_PE686092_S5.JPG","url":"https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0612906_pe686092_s5.jpg","type":"MEASUREMENT_ILLUSTRATION"}}],"mediaList":[{"type":"image","content":{"alt":"POÄNG Sillón, chapa abedul/Hillared beige","id":"0497125_PE628952","imageFileName":"0497125_PE628952_S5.JPG","url":"https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg","type":"MAIN_PRODUCT_IMAGE"}},{"type":"image","content":{"alt":"POÄNG Sillón, chapa abedul/Hillared beige","id":"0837582_PE629074","imageFileName":"0837582_PE629074_S5.JPG","url":"https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0837582_pe629074_s5.jpg","type":"CONTEXT_PRODUCT_IMAGE"}},{"type":"image","content":{"alt":"POÄNG Sillón, chapa abedul/Hillared beige","id":"0837579_PE628955","imageFileName":"0837579_PE628955_S5.JPG","url":"https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0837579_pe628955_s5.jpg","type":"FUNCTIONAL_PRODUCT_IMAGE"}},{"type":"image","content":{"alt":"POÄNG Sillón, chapa abedul/Hillared beige","id":"0837573_PE628954","imageFileName":"0837573_PE628954_S5.JPG","url":"https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0837573_pe628954_s5.jpg","type":"QUALITY_PRODUCT_IMAGE"}},{"type":"image","content":{"alt":"POÄNG Sillón, chapa abedul/Hillared beige","id":"0612906_PE686092","imageFileName":"0612906_PE686092_S5.JPG","url":"https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0612906_pe686092_s5.jpg","type":"MEASUREMENT_ILLUSTRATION"}}],"heroesCount":0,"isDoubleHero":false,"isSingleHero":false,"disabledButton":true,"buttonMoreLabel":"Mostrar más imágenes","buttonLessLabel":"Mostrar menos","barPosition":0,"barWidth":20,"isSingleMedia":false,"energyLabelProps":null}'>
#          <div class="range-revamp-media-grid__mobile-info">
#           <div class="range-revamp-media-grid__mobile-info-inner">
#           </div>
#          </div>
#          <div class="range-revamp-media-grid__grid">
#           <div class="range-revamp-media-grid__media-container">
# ...
#                      <div class="range-revamp-product-compact__bottom-wrapper">
#                       <div class="range-revamp-compact-price-package">
#                        <div class="range-revamp-compact-price-package__additional-info">
#                         <div class="range-revamp-header-section">
#                          <div class="range-revamp-header-section__title--small" style="text-decoration: none; background-color: #f5f5f5;">
#                          </div>
#                          <div class="range-revamp-header-section__description" style="background-color: #f5f5f5;">
#                          </div>
#                         </div>
#                        </div>
#                        <div class="range-revamp-compact-price-package__price-wrapper" style="display: block;  background-color: #f5f5f5;">
#                        </div>
#                        <span class="range-revamp-compact-price-package__variations-disclaimer" style="background-color: #f5f5f5;">
#                        </span>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <button aria-controls="rec-carousel__default" aria-label="See next items" class="rec-btn rec-btn--icon-primary rec-carousel__button rec-carousel__button--right" id="rec-carousel-kdm1zfge1u9__next-btn" type="button">
#                 <span class="rec-btn__inner rec-btn__inner--icon-primary rec-btn--small">
#                  <span class="rec-btn__copy">
#                   <svg aria-hidden="true" class="rec-svg-icon rec-btn__icon" focusable="false" viewbox="0 0 24 24">
#                    <path clip-rule="evenodd" d="M16.415 12.001l-8.001 8L7 18.588l6.587-6.586L7 5.414 8.415 4l8 8.001z" fill-rule="evenodd">
#                    </path>
#                   </svg>
#                  </span>
#                 </span>
#                </button>
#               </div>
#               <div class="rec-scroll-indicator" tabindex="0">
#               </div>
#               <a id="rec-carousel-pkwhdylw9l__skip-btn">
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="js-sticky-product-bar range-revamp-sticky-product-bar-wrapper">
#        <div class="range-revamp-sticky-product-bar">
#         <div class="range-revamp-sticky-product-bar__image">
#          <span class="range-revamp-aspect-ratio-image range-revamp-aspect-ratio-image--square">
#           <img alt="POÄNG Sillón, chapa abedul/Hillared beige" class="range-revamp-aspect-ratio-image__image" data-src="false" data-src-set="false" loading="lazy" sizes="40px" src="https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg?f=xu" srcset="
#   https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg?f=g 1600w,
#   https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg?f=sg 1400w,
#   https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg?f=xxxl 1100w,
#   https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg?f=xxl 900w,
#   https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg?f=xl 750w,
#   https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg?f=l 700w,
#   https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg?f=m 600w,
#   https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg?f=s 500w,
#   https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg?f=xs 400w,
#   https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg?f=xxs 300w,
#   https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg?f=xxxs 160w,
#   https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg?f=u 80w,
#   https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg?f=xu 40w,
#   https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg?f=xxu 39w
# "/>
#          </span>
#         </div>
#         <div class="range-revamp-sticky-product-bar__info-wrapper">
#          <p class="range-revamp-sticky-product-bar-title product-title-small notranslate">
#           POÄNG
#          </p>
#          <button class="range-revamp-sticky-product-bar-details-button sticky-product-bar__details-cta" type="button">
#           <label class="js-sticky-scroll-to-price range-revamp-sticky-product-bar-details-button__label">
#            Ver detalles
#           </label>
#          </button>
#         </div>
#         <div class="range-revamp-sticky-product-bar__price">
#          <div class="range-revamp-pip-price-package__price-wrapper">
#           <div class="range-revamp-pip-price-package__main-price">
#            <span class="range-revamp-price">
#             <span class="range-revamp-price__currency-symbol range-revamp-price__currency-symbol--leading range-revamp-price__currency-symbol--superscript">
#              $
#             </span>
#             <span class="range-revamp-price__integer">
#              2 999
#             </span>
#            </span>
#           </div>
#          </div>
#         </div>
#         <div class="js-sticky-cart-button-props" data-currency="MXN" data-is-food="false" data-online-sellable="false" data-product-number="09306567" data-product-price="2999" data-product-type="SPR" data-ratings="0">
#         </div>
#         <button class="range-revamp-btn range-revamp-btn--small range-revamp-btn--icon-emphasised js-sticky-buy-button" type="button">
#          <span class="range-revamp-btn__inner">
#           <svg aria-hidden="true" class="range-revamp-svg-icon range-revamp-btn__icon" focusable="false" viewbox="0 0 24 24">
#            <path clip-rule="evenodd" d="M10.4372 4H10.9993H12.0003H12.9996H13.5616L13.8538 4.48014L17.2112 9.99713H21H22.2806L21.9702 11.2396L21.5303 13H19.4688L19.7194 11.9971H4.28079L5.59143 17.2397C5.70272 17.6848 6.1027 17.9971 6.56157 17.9971H15V19.9971H6.56157C5.18496 19.9971 3.98502 19.0602 3.65114 17.7247L2.02987 11.2397L1.71924 9.99713H3.00002H6.78793L10.145 4.48017L10.4372 4ZM12.4375 6L14.87 9.99713H9.12911L11.5614 6H12.0003H12.4375ZM17.9961 16V14H19.9961V16H21.9961V18H19.9961V20H17.9961V18H15.9961V16H17.9961Z" fill-rule="evenodd">
#            </path>
#           </svg>
#          </span>
#         </button>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </main>
#   <!-- 2021-05-11T11:07:33.229Z, Navigera 2.4.4 -->
#   <div data-recently-viewed="true">
#   </div>
#   <div class="hnf-sidebar-actions">
#    <div class="hnf-sidebar-actions__inner">
#     <div class="hnf-sidebar-actions__aside">
#      <div class="hnf-sidebar-actions__bar" id="sidebar">
#       <button class="hnf-btn hnf-btn--small hnf-leading-icon hnf-btn--primary hnf-btn--expanding hnf-sidebar-actions__back-to-top expanding-button" id="btn-back-to-top" tabindex="-1" type="button">
#        <span class="hnf-btn__inner">
#         <svg class="svg-icon hnf-svg-icon hnf-btn__icon" fill="none" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#          <path clip-rule="evenodd" d="M12 6.94l8 8-1.413 1.415L12 9.768l-6.587 6.586L4 14.94l8.001-8z" fill-rule="evenodd">
#          </path>
#         </svg>
#         <span class="hnf-btn__label">
#          Volver al inicio
#         </span>
#        </span>
#       </button>
#       <button class="hnf-btn hnf-btn--small hnf-leading-icon hnf-btn--primary hnf-btn--expanding hnf-sidebar-actions__share-to-socialmedia js-btn-hnf-share-to-socialmedia expanding-button expanding-button--visible" data-service="socialSharingPanel" role="button" type="button">
#        <span class="hnf-btn__inner">
#         <svg class="svg-icon hnf-svg-icon hnf-btn__icon" fill="none" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#          <path d="M11 7.83l-3.242 3.24-1.414-1.413L12 4l5.657 5.657-1.414 1.414L13 7.828V16h-2V7.83z">
#          </path>
#          <path d="M2 21.003h20v-9h-2v7H4v-7H2v9z">
#          </path>
#         </svg>
#         <span class="hnf-btn__label">
#          Compartir
#         </span>
#        </span>
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <footer class="hnf-footer" role="contentinfo">
#    <h-include-lazy src="https://www.ikea.com/mx/es/header-footer/footer-lazy-fragment.html">
#    </h-include-lazy>
#   </footer>
#   <!-- 2021-05-11T11:07:33.206Z, Navigera 2.4.4 -->
#   <script src="https://polyfill.ikea.net/v3/polyfill.min.js?features=Promise%2CIntersectionObserver%2CElement.prototype.closest%2Cfetch%2CArray.from&amp;flags=gated">
#   </script>
#   <script>
#    this.customElements||document.write('<script src="https://www.ikea.com/mx/es/header-footer/javascripts/document-register-element.js"><\x2fscript>');
#   </script>
#   <script data-domain="www.ikea.com" data-intext="false" data-release="2.4.4" data-sentry="false" data-site-folder="mx/es" id="nav-script-common" src="https://www.ikea.com/mx/es/header-footer/javascripts/common.23a0cadfd69d2cafcee1.js">
#   </script>
#   <script src="https://www.ikea.com/mx/es/header-footer/javascripts/main.d5bb5c9d673b569e5a98.js">
#   </script>
#   <script async="" defer="defer" src="https://www.ikea.com/mx/es/analytics/scripts/ga-main.98d561d0.js">
#   </script>
#   <script async="" defer="defer" src="https://www.ikea.com/mx/es/analytics/scripts/ga-targeting.98d561d0.js">
#   </script>
#   <script async="" defer="defer" src="https://www.ikea.com/mx/es/analytics/scripts/boomerang.min.js?98d561d059da4fd36015">
#   </script>
#   <script>
#    window.isLandingPage =
#     document.referrer.split('/')[2] !== location.host ? true : false;
#   window.analyticsQueue = window.analyticsQueue || [];
#   window.sendEvent = function (evt) {
#     window.analyticsQueue.push(evt);
#   };
#
#   window.ikea.analytics = {
#     observeProducts: [],
#   };
#   </script>
#   <!-- 2021-05-12 16:08:08 CEST Search: refs/tags/v8.76.0-62d6a79694c183571ba95b677179aa4fa6745eff -->
#   <link href="https://sik.search.blue.cdtapps.com" rel="preconnect"/>
#   <script src="https://www.ikea.com/mx/es/search/shared.f849b6f5.js" type="module">
#   </script>
#   <script src="https://www.ikea.com/mx/es/search/search_vendors.f849b6f5.js" type="module">
#   </script>
#   <script nomodule="" src="https://www.ikea.com/mx/es/search/box-legacy.f849b6f5.js">
#   </script>
#   <script src="https://www.ikea.com/mx/es/search/box.f849b6f5.js" type="module">
#   </script>
#   <!-- RecommendationsScript: version: bd3f9a8, site-folder: mx/es -->
#   <script>
#    if (window && window.ikea && window.ikea.sentry && window.ikea.sentry.register) {
#     window.ikea.sentry.register('5583489', '10bb11cc3ff548e295b5e960579d8042', 'recommendations', 'bd3f9a8', 0.1, [/\/[a-z0-9]{2}\/[a-z0-9]{2}\/recommendations\/panels\//]);
#   }
#   </script>
#   <script defer="defer" src="https://www.ikea.com/mx/es/recommendations/panels/events.e26d1a84.js" type="module">
#   </script>
#   <script defer="defer" src="https://www.ikea.com/mx/es/recommendations/panels/rec.e26d1a84.js" type="module">
#   </script>
#   <!-- /RecommendationsScript -->
#   <!-- gitVersion: refs/tags/v0.1.5, siteFolder: mx/es -->
#   <script defer="defer" src="https://www.ikea.com/mx/es/purchase-agent/cart-tmp/vendor.cb2751c0.js">
#   </script>
#   <script defer="defer" src="https://www.ikea.com/mx/es/purchase-agent/cart-tmp/purchase-middleware-base.c8447df4.js">
#   </script>
#   <!--list-agent-->
#   <!-- igift-agent-disabled -->
#   <!-- Feed gitVersion: 20210511211300, siteFolder: mx/es -->
#   <script>
#    if (window && window.ikea && window.ikea.sentry && window.ikea.sentry.register) {
#     window.ikea.sentry.register('5244394', '4def75a18cb34ab59e68a690be123979', 'feed', '20210511211300', 0.1, [/\/[a-z0-9]{2}\/[a-z0-9]{2}\/insp-feed\/content-gallery-app\//]);
#   }
#   </script>
#   <script src="https://polyfill.ikea.net/v3/polyfill.min.js?features=Element.prototype.append%2Cdefault%2CPromise%2Ces2017%2Ces2018%2Ces5%2Ces6%2Ces7%2Cfetch&amp;flags=gated">
#   </script>
#   <script defer="defer" src="https://www.ikea.com/mx/es/insp-feed/content-gallery-app/feed.25cf3909.js">
#   </script>
#   <div class="is-mobile" id="js-is-mobile">
#   </div>
#   <script id="range__page-meta-data" type="application/json">
#    {"correctUrl":"/mx/es/p/poaeng-sillon-chapa-abedul-hillared-beige-s09306567/"}
#   </script>
#   <!-- Range PIP app - Version:v56 -->
#   <script src="/mx/es/products/javascripts/range-vendor.1bdd2ccb8fb777f5df3a.js">
#   </script>
#   <script src="/mx/es/products/javascripts/range-pip-main.e8f3d7d578170651d5d5.js">
#   </script>
#   <!-- 2021-05-11T11:07:33.207Z, Navigera 2.4.4 -->
#   <script src="https://www.ikea.com/mx/es/local-extensions/header-footer/scripts/main.1c73f896c69b734fa167043a.js">
#   </script>
#   <!-- Local Development -->
#   <!-- Marketing Scripts Below -->
#   <script defer="" src="https://www.ikea.com/mx/es/local-extensions/header-footer/scripts/contentsquare.4268741bd7d93a2f27218576.js">
#   </script>
#   <script defer="" src="https://www.ikea.com/mx/es/local-extensions/header-footer/scripts/gtag.af3c7b487b4b408d112b5c2e.js">
#   </script>
#   <script defer="" src="https://www.ikea.com/mx/es/local-extensions/header-footer/scripts/facebook.ef661bb67fd4baee0c52ae0c.js">
#   </script>
#   <script id="js-range-market-messaging-global" type="application/json">
#    {"DELIVERY_MESSAGE":{"text":"Por el momento, nuestro servicio de entrega a domicilio solo está disponible para la CDMX, Toluca y 21 municipios del Estado de México, así como determinados códigos postales en Hidalgo, Jalisco, Morelos, Puebla, Querétaro y Tlaxcala. Este producto también está disponible para compra en tienda, con entrega a domicilio."}}
#   </script>
#   <span>
#   </span>
#   <script id="pip-range-json-ld" type="application/ld+json">
#    {"@context":"https://schema.org/","@type":"Product","name":"POÄNG Sillón - chapa abedul/Hillared beige","image":["https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0497125_pe628952_s5.jpg","https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0837582_pe629074_s5.jpg","https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0837579_pe628955_s5.jpg","https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0837573_pe628954_s5.jpg","https://www.ikea.com/mx/es/images/products/poaeng-sillon-chapa-abedul-hillared-beige__0612906_pe686092_s5.jpg"],"description":"POÄNG Sillón - chapa abedul/Hillared beige. El respaldo alto proporciona un buen apoyo al cuello. Con nuestro surtido variado de cojines podrás renovar fácilmente el aspecto de POÄNG y de la habitación. Si lo combinas con el taburete POÄNG, el sillón será aún más cómodo.","url":"https://www.ikea.com/mx/es/p/poaeng-sillon-chapa-abedul-hillared-beige-s09306567/","sku":"093.065.67","mpn":"093.065.67","brand":{"@type":"Thing","name":"IKEA"},"offers":{"@type":"Offer","url":"https://www.ikea.com/mx/es/p/poaeng-sillon-chapa-abedul-hillared-beige-s09306567/","priceCurrency":"MXN","price":"2999","itemCondition":"https://schema.org/NewCondition","availability":"https://schema.org/OutOfStock","seller":{"@type":"Organization","name":"IKEA"}}}
#   </script>
#   <script type="text/javascript">
#    var _cf = _cf || [];  _cf.push(['_setFsp', true]);  _cf.push(['_setBm', true]);  _cf.push(['_setAu', '/resources/cf149f2fdarn18824071acaf63b5de73']);
#   </script>
#   <script src="https://www.ikea.com/resources/cf149f2fdarn18824071acaf63b5de73" type="text/javascript">
#   </script>
#  </body>
# </html>

# %% [markdown]
# Now, let's try to get the **name of the article**. The following code checks if the tag exists, in case it is changed in the future.

# %%
try:
    article = bs.body.h1.get_text()

except AttributeError as e:
    print('Tag was not found')
    
else:
    if article == None:
        print('Tag was not found')
    else:
        print(article)
# Out:
# POÄNGSillón, chapa abedul/Hillared beige

# %% [markdown]
# Now we can save it all as a function:

# %%
def get_article_name(url):
    """Returns the name and availability of an IKEA product"""
    
    try:
        html = urlopen(url)
    except HTTPError as e: # Page is not found
        print(e)
    except URLError as e: # Page is down
        print('The server could not be found!')
    
    else:
        try: 
            bs = BeautifulSoup(html, 'lxml')
            article = bs.body.h1.get_text()
        except AttributeError as e: # Tag is not found
            print('Tag was not found')
        
        if article == None:
            print('Tag was not found')

        return article

# %%
get_article_name(url)
# Out:
# 'POÄNGSillón, chapa abedul/Hillared beige'

# %%
def get_article_availability(url):
